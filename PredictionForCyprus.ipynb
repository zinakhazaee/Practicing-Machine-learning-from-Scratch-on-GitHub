# %% [markdown]
# <a href="https://colab.research.google.com/github/zinakhazaee/Practicing-Machine-learning-from-Scratch-on-GitHub/blob/main/PredictionForCyprus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# %% [markdown]
# # load data

# %%
oecd_bli = pd.read_excel("/content/drive/MyDrive/datasets_sample/oecd.xlsx")
gdp_per_capita = pd.read_excel("/content/drive/MyDrive/datasets_sample/gdp_per_capita.xlsx")

# %%
oecd_bli
# Out:
#             country  Life Satisfaction
# 0         Australia                7.1
# 1           Austria                7.2
# 2           Belgium                6.8
# 3            Canada                7.0
# 4             Chile                6.2
# 5          Colombia                5.7
# 6        Costa Rica                6.3
# 7           Czechia                6.9
# 8           Denmark                7.5
# 9           Estonia                6.5
# 10          Finland                7.9
# 11           France                6.7
# 12          Germany                7.3
# 13           Greece                5.8
# 14          Hungary                6.0
# 15          Iceland                7.6
# 16          Ireland                7.0
# 17           Israel                7.2
# 18            Italy                6.5
# 19            Japan                6.1
# 20            Korea                5.8
# 21           Latvia                6.2
# 22        Lithuania                6.4
# ...

# %%
gdp_per_capita
# Out:
#                         GDPpercapita      value
# 0                        Afghanistan    no data
# 1                            Albania   8924.317
# 2                            Algeria   5721.678
# 3                            Andorra  44899.596
# 4                             Angola    2431.58
# ..                               ...        ...
# 222  Latin America and the Caribbean  10878.689
# 223    Major advanced economies (G7)  62412.739
# 224     Middle East and Central Asia    5744.87
# 225         Other advanced economies  51506.626
# 226               Sub-Saharan Africa   1620.972
#
# [227 rows x 2 columns]

# %% [markdown]
# # Prepare Data

# %%
country_stats = pd.merge(oecd_bli, gdp_per_capita, left_on= 'country',right_on= 'GDPpercapita'  , how='inner')

# %%
country_stats
# Out:
#             country  Life Satisfaction     GDPpercapita       value
# 0         Australia                7.1        Australia   66589.055
# 1           Austria                7.2          Austria    59225.15
# 2           Belgium                6.8          Belgium   55536.223
# 3            Canada                7.0           Canada   54866.046
# 4             Chile                6.2            Chile   16616.231
# 5          Colombia                5.7         Colombia    7327.118
# 6        Costa Rica                6.3       Costa Rica   18030.977
# 7           Denmark                7.5          Denmark   68897.547
# 8           Estonia                6.5          Estonia   31854.782
# 9           Finland                7.9          Finland   55126.995
# 10           France                6.7           France   47358.557
# 11          Germany                7.3          Germany   54290.944
# 12           Greece                5.8           Greece   23965.779
# ...

# %%
X = np.c_[country_stats["value"]]
y = np.c_[country_stats["Life Satisfaction"]]

# %%
country_stats.plot(kind='scatter', x="value", y='Life Satisfaction')
plt.show()

# %% [markdown]
# # Select a linear model

# %%
model = sklearn.linear_model.LinearRegression()

# %% [markdown]
# # Train the model

# %%
model
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# # Make a prediction for Cyprus (GDP per capita)

# %%
X_new = [[22587]]
print(model.predict(X_new))
# Out:
# [[6.3213776]]
